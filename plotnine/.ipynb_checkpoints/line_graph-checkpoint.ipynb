# %%
from plotnine import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# C:\Python\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
pg_mean= pd.read_csv("./data/pg_mean.csv")
BOD = pd.DataFrame({"Time":[1,2,3,4,5,7],'demand':[8.3,10.3,19.0,16.0,15.6,19.8]})
cabbage_exp = pd.read_csv("./data/cabbage_exp.csv")
diamonds = pd.read_csv("./data/diamonds.csv")
upc = pd.read_csv("./data/upc.csv")
csub = pd.read_csv("./data/csub.csv")
tophitters2001 = pd.read_csv("./data/tophitters2001.csv")

# %%
worldpop = pd.read_csv("./data/worldpop.csv")

# %%
ToothGrowth = pd.read_csv("./data/ToothGrowth.csv")

# %%
uspopage = pd.read_csv("./data/uspopage.csv")

# %%
climate = pd.read_csv("./data/climate.csv")

# %% [markdown]
# # Line Graph

# %% [markdown]
# ## Basic Line Graph

# %%
(ggplot(BOD,aes("Time",'demand')) +
 geom_line()
)
# Out:
# <ggplot: (-9223371927113909069)>

# %% [markdown]
# ## Points in Line Graph

# %%
(ggplot(BOD,aes("Time",'demand')) +
 geom_line() + geom_point()
)
# Out:
# <ggplot: (109741251304)>

# %%
(ggplot(worldpop,aes('Year','Population')) + 
 geom_line() + geom_point() + scale_y_log10()
)
# Out:
# <ggplot: (-9223371927113347580)>

# %% [markdown]
# ## Line Graph With Multiple Lines

# %%
ToothGrowth.drop('Unnamed: 0',axis=1,inplace=True)
tg = ToothGrowth.groupby(['supp','dose']).sum()
tg.reset_index(level=['supp', 'dose'],inplace=True)

# %%
(ggplot(tg,aes(x='dose',y='len',color='supp',linetype='supp',shape='supp')) +
 geom_line(position=position_dodge(0.1),size=2) + geom_point(position=position_dodge(0.1),size=4) +
 scale_colour_brewer(palette="YlGn")
)
# Out:
# <ggplot: (109743069462)>

# %% [markdown]
# ## Change the Appearance of Lines

# %%
(ggplot(BOD, aes(x='Time', y='demand')) +
 geom_line(linetype="--", size=2, color="skyblue") +
 geom_point(size=4,shape='D',color='darkred',fill='pink')
)
# Out:
# <ggplot: (109741259577)>

# %% [markdown]
# ## Stacked Area Graph -_- fill can not in order

# %%
# age_order ={'<5':1,'5-14':2,'15-24':3,'25-34':4,'35-44':5,'45-54':6,'55-64':7,'>64':8}
# uspopage['age_ord'] = uspopage['AgeGroup'].apply(lambda x: age_order[x])
# uspopage.sort_values('age_ord',inplace=True)

# %%
(ggplot(uspopage,aes('Year','Thousands',fill='AgeGroup')) +
 geom_area(alpha=0.85)
)
# ['<5', '5-14', '15-24', '25-34', '35-44', '45-54', '55-64', '>64']
# Out:
# <ggplot: (-9223371927110910008)>

# %% [markdown]
# ## Proportional Stacked Area Graph -_- fill can not in order

# %%
uspopage_prop = uspopage.copy()
uspopage_prop['percent'] =uspopage_prop.groupby('Year')['Thousands'].transform(lambda x:x / x.sum() * 100)

# %%
(ggplot(uspopage_prop,aes('Year','percent',fill='AgeGroup')) +
 geom_area(alpha=0.85)
)
# Out:
# <ggplot: (-9223371927111094924)>

# %% [markdown]
# ## Confidence Region

# %%
clim = climate.loc[climate['Source']=="Berkeley",["Year", "Anomaly10y", "Unc10y"]].copy()
y_max = clim['Anomaly10y'] + clim['Unc10y']
y_min = clim['Anomaly10y'] - clim['Unc10y']

# %%
(ggplot(clim, aes(x='Year', y='Anomaly10y')) +
 geom_ribbon(aes(ymin=y_min, ymax=y_max),alpha=0.2) +
 geom_line()
)
# Out:
# <ggplot: (109743124719)>

# %%
(ggplot(clim, aes(x='Year', y='Anomaly10y')) +
 geom_line(aes(y=y_min), colour="grey", linetype="--") +
 geom_line(aes(y=y_max), colour="grey", linetype="--") +
 geom_line()
)
# Out:
# <ggplot: (109741449238)>
